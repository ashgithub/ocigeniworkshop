# %% [markdown]
# # OCI language
#
# Small Language Models can be cheaper and better for arious languge tasks.
#
# 1. sentiment analysius
# 1. key phrase extraction
# 1. named entity extraction
# 1. text classification
# 1. PII identification & masking
# 1. language detection
# 1. translation
#
# see sdk at  at : https://github.com/oracle/oci-python-sdk/blob/22fd62c8dbbd1aaed6b75754ec1ba8a3c16a4e5a/src/oci/ai_language/ai_service_language_client.py#L584
# documentation at : https://docs.oracle.com/en-us/iaas/language/using/home.htm
#
# if you have errors running sample code reach out for help in #igiu-ai-learning

# %% [markdown]
# ## Sentiment Analysis
#
# Aspects:  Topics or concepts withn in text
# Sentences:  sentiment for the entire sentences
#
# https://docs.oracle.com/en-us/iaas/language/using/sentment.htm

# %%
import oci, os, json 
from dotenv import load_dotenv
from envyaml import EnvYAML

#####
#make sure your sandbox.yaml file is setup for your environment. You might have to specify the full path depending on  your `cwd` 
#####
SANDBOX_CONFIG_FILE = "sandbox.yaml"


# read the sandbox config 
scfg = EnvYAML(SANDBOX_CONFIG_FILE)
                
#read the oci config
config = oci.config.from_file(os.path.expanduser(scfg["oci"]["configFile"]),scfg["oci"]["profile"])

compartmentId=  scfg["oci"]["compartment"]


lang_client = oci.ai_language.AIServiceLanguageClient(config)


test_string1 = """
    Oracle Cloud Infrastructure is built for enterprises seeking higher performance, lower costs, and easier cloud migration for their applications. 
    Customers choose Oracle Cloud Infrastructure over AWS for several reasons:
    First, they can consume cloud services in the public cloud or within their  own data center with Oracle Dedicated Region Cloud@Customer. 
    Second, they can migrate and run any workload as is on Oracle Cloud, including Oracle databases and applications, VMware, or bare metal servers. 
    Third, customers can easily implement security controls and automation to prevent misconfiguration errors and implement security best practices. 
    Fourth, they have lower risks with Oracle’s end-to-end SLAs covering performance, availability, and manageability of services. 
    Finally, their workloads achieve better performance at a significantly lower cost with Oracle Cloud Infrastructure than AWS.
    
    Take a look at what makes Oracle Cloud Infrastructure a better cloud platform than AWS."
"""
test_string2 = " The restaurant Chinese Garden on 100  Broadway, Denver, CO-80503 serves delicious meal, but the food can be expensive."
test_string3 = " The wet, slushy rain in Denver can lead to accidents, but if yuo send an emai to help@denver.org they will come out and help which is awesome"

test_doc1 = oci.ai_language.models.TextDocument(
        key="oci",
        text=test_string1,
        language_code="en"
        )

test_doc2 = oci.ai_language.models.TextDocument(
        key="chinese_garden",
        text=test_string2,
        language_code="en"
        )
test_doc3 = oci.ai_language.models.TextDocument(
        key="Denver",
        text=test_string3,
        language_code="en"
        )

test_docs=[test_doc1, test_doc2, test_doc3]

# %%
#Sentiment analysis - aspect

senti_details =oci.ai_language.models.BatchDetectLanguageSentimentsDetails(
    documents = test_docs,
    compartment_id = compartmentId)

senti_res = lang_client.batch_detect_language_sentiments(batch_detect_language_sentiments_details=senti_details , level=["ASPECT"] )

print (senti_res.data)
# Out:
# {
#   "documents": [
#     {
#       "aspects": [
#         {
#           "length": 11,
#           "offset": 848,
#           "scores": {
#             "Mixed": 0.0020396360867446527,
#             "Negative": 0.027223763183745562,
#             "Neutral": 0.0,
#             "Positive": 0.9707366007295097
#           },
#           "sentiment": "Positive",
#           "text": "performance"
#         }
#       ],
#       "document_scores": {},
#       "document_sentiment": "",
#       "key": "oci",
#       "language_code": "en",
#       "sentences": []
#     },
#     {
#       "aspects": [
#         {
#           "length": 25,
#           "offset": 5,
#           "scores": {
#             "Mixed": 0.3645064378733929,
#             "Negative": 0.005917448460160917,
#             "Neutral": 0.0,
#             "Positive": 0.6295761136664463
#           },
#           "sentiment": "Positive",
#           "text": "restaurant Chinese Garden"
#         },
#         {
#           "length": 4,
#           "offset": 83,
#           "scores": {
#             "Mixed": 0.01222333364027984,
#             "Negative": 0.0,
#             "Neutral": 0.0030766990523965108,
#             "Positive": 0.9846999673073236
#           },
#           "sentiment": "Positive",
#           "text": "meal"
#         },
#         {
#           "length": 4,
#           "offset": 97,
#           "scores": {
#             "Mixed": 0.03767601730968586,
#             "Negative": 0.9069401838714787,
#             "Neutral": 0.0,
#             "Positive": 0.0553837988188354
#           },
#           "sentiment": "Negative",
#           "text": "food"
#         }
#       ],
#       "document_scores": {},
#       "document_sentiment": "",
#       "key": "chinese_garden",
#       "language_code": "en",
#       "sentences": []
#     },
#     {
#       "aspects": [],
#       "document_scores": {},
#       "document_sentiment": "",
#       "key": "Denver",
#       "language_code": "en",
#       "sentences": []
#     }
#   ],
#   "errors": []
# }

# %%
#Sentiment analysis - sentence

senti_details =oci.ai_language.models.BatchDetectLanguageSentimentsDetails(
    documents=test_docs,
    compartment_id = compartmentId)

senti_res = lang_client.batch_detect_language_sentiments(batch_detect_language_sentiments_details=senti_details , level=["SENTENCE"] )

print (senti_res.data)
# Out:
# {
#   "documents": [
#     {
#       "aspects": [],
#       "document_scores": {
#         "Mixed": 0.5821406,
#         "Negative": 0.03710457,
#         "Neutral": 0.24640831,
#         "Positive": 0.13434651
#       },
#       "document_sentiment": "Mixed",
#       "key": "oci",
#       "language_code": "en",
#       "sentences": [
#         {
#           "length": 144,
#           "offset": 0,
#           "scores": {
#             "Mixed": 0.2640824,
#             "Negative": 0.0034531013,
#             "Neutral": 0.56717134,
#             "Positive": 0.16529317
#           },
#           "sentiment": "Neutral",
#           "text": "Oracle Cloud Infrastructure is built for enterprises seeking higher performance, lower costs, and easier cloud migration for their applications."
#         },
#         {
#           "length": 210,
#           "offset": 145,
#           "scores": {
#             "Mixed": 0.02488376,
#             "Negative": 0.0,
#             "Neutral": 0.86399716,
#             "Positive": 0.11111911
#           },
#           "sentiment": "Neutral",
#           "text": "Customers choose Oracle Cloud Infrastructure over AWS for several reasons: First, they can consume cloud services in the public cloud or within their own data center with Oracle Dedicated Region Cloud@Customer."
#         },
#         {
#           "length": 144,
#           "offset": 356,
#           "scores": {
#             "Mixed": 0.027632022,
#             "Negative": 0.015702276,
#             "Neutral": 0.713563,
#             "Positive": 0.24310267
#           },
#           "sentiment": "Neutral",
#           "text": "Second, they can migrate and run any workload as is on Oracle Cloud, including Oracle databases and applications, VMware, or bare metal servers."
#         },
#         {
#           "length": 144,
#           "offset": 501,
#           "scores": {
#             "Mixed": 0.034679446,
#             "Negative": 0.0437425,
#             "Neutral": 0.51983416,
#             "Positive": 0.4017439
#           },
#           "sentiment": "Neutral",
#           "text": "Third, customers can easily implement security controls and automation to prevent misconfiguration errors and implement security best practices."
#         },
#         {
#           "length": 126,
#           "offset": 646,
#           "scores": {
#             "Mixed": 0.7013764,
#             "Negative": 0.04951702,
#             "Neutral": 0.22020511,
#             "Positive": 0.028901499
#           },
#           "sentiment": "Mixed",
#           "text": "Fourth, they have lower risks with Oracle’s end-to-end SLAs covering performance, availability, and manageability of services."
#         },
#         {
#           "length": 124,
#           "offset": 773,
#           "scores": {
#             "Mixed": 0.61454296,
#             "Negative": 0.0056145596,
#             "Neutral": 0.1536646,
#             "Positive": 0.22617789
#           },
#           "sentiment": "Mixed",
#           "text": "Finally, their workloads achieve better performance at a significantly lower cost with Oracle Cloud Infrastructure than AWS."
#         },
#         {
#           "length": 88,
#           "offset": 898,
#           "scores": {
#             "Mixed": 0.43050247,
#             "Negative": 0.056182127,
#             "Neutral": 0.36535522,
#             "Positive": 0.14796017
#           },
#           "sentiment": "Mixed",
#           "text": "Take a look at what makes Oracle Cloud Infrastructure a better cloud platform than AWS.\""
#         }
#       ]
#     },
#     {
#       "aspects": [],
#       "document_scores": {
#         "Mixed": 0.9908483,
#         "Negative": 0.0,
#         "Neutral": 0.0,
#         "Positive": 0.009151701
#       },
#       "document_sentiment": "Mixed",
#       "key": "chinese_garden",
#       "language_code": "en",
#       "sentences": [
#         {
#           "length": 117,
#           "offset": 0,
#           "scores": {
#             "Mixed": 0.9908483,
#             "Negative": 0.0,
#             "Neutral": 0.0,
#             "Positive": 0.009151701
#           },
#           "sentiment": "Mixed",
#           "text": "The restaurant Chinese Garden on 100 Broadway, Denver, CO-80503 serves delicious meal, but the food can be expensive."
#         }
#       ]
#     },
#     {
#       "aspects": [],
#       "document_scores": {
#         "Mixed": 0.680209,
#         "Negative": 0.031718485,
#         "Neutral": 0.064447746,
#         "Positive": 0.22362477
#       },
#       "document_sentiment": "Mixed",
#       "key": "Denver",
#       "language_code": "en",
#       "sentences": [
#         {
#           "length": 141,
#           "offset": 0,
#           "scores": {
#             "Mixed": 0.680209,
#             "Negative": 0.031718485,
#             "Neutral": 0.064447746,
#             "Positive": 0.22362477
#           },
#           "sentiment": "Mixed",
#           "text": "The wet, slushy rain in Denver can lead to accidents, but if yuo send an emai to help@denver.org they will come out and help which is awesome"
#         }
#       ]
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# ## Key Phrase Extraction

# %%
keyphrase_extraction = lang_client.batch_detect_language_key_phrases(
            batch_detect_language_key_phrases_details=oci.ai_language.models.BatchDetectLanguageKeyPhrasesDetails(documents=test_docs,compartment_id = compartmentId)
        )
         
print(keyphrase_extraction.data)
# Out:
# {
#   "documents": [
#     {
#       "key": "oci",
#       "key_phrases": [
#         {
#           "score": 0.9999999999932061,
#           "text": "oracle cloud infrastructure"
#         },
#         {
#           "score": 0.9999999995580071,
#           "text": "aws"
#         },
#         {
#           "score": 0.9999999641285948,
#           "text": "oracle cloud"
#         },
#         {
#           "score": 0.9999994197569447,
#           "text": "customers"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "higher performance"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "lower costs"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "easier cloud migration"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "several reasons"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "cloud services"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "public cloud"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "own data center"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "including oracle"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "databases and applications"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "bare metal servers ."
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "security controls and automation"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "misconfiguration errors"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "security best practices"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "lower risks"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "oracle's end-to-end slas"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "covering performance"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "manageability of services"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "better performance"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "lower cost"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "better cloud platform"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "enterprises"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "applications"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "vmware"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "availability"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "workloads"
#         },
#         {
#           "score": 0.9821892900152369,
#           "text": "workload"
#         }
#       ],
#       "language_code": "en"
#     },
#     {
#       "key": "chinese_garden",
#       "key_phrases": [
#         {
#           "score": 0.9998106383818767,
#           "text": "restaurant chinese garden"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "100 broadway"
#         },
#         {
#           "score": 0.9998106383818767,
#           "text": "delicious meal"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "denver"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "co-80503"
#         },
#         {
#           "score": 0.9899982845720443,
#           "text": "food"
#         }
#       ],
#       "language_code": "en"
#     },
#     {
#       "key": "Denver",
#       "key_phrases": [
#         {
#           "score": 0.9998106383818767,
#           "text": "slushy rain"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "wet"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "denver"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "accidents"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "emai"
#         },
#         {
#           "score": 0.999238842713225,
#           "text": "help@denver.org"
#         }
#       ],
#       "language_code": "en"
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# ## Named Entity Extractions
#
# see : https://docs.oracle.com/en-us/iaas/language/using/ner.htm

# %%
ner_extraction = lang_client.batch_detect_language_entities(
            batch_detect_language_entities_details=oci.ai_language.models.BatchDetectLanguageEntitiesDetails(documents=test_docs,compartment_id = compartmentId)
        )
         
print(ner_extraction.data)
# Out:
# {
#   "documents": [
#     {
#       "entities": [
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 5,
#           "score": 0.6449366211891174,
#           "sub_type": null,
#           "text": "Oracle",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 20,
#           "meta_info": null,
#           "offset": 12,
#           "score": 0.6921470761299133,
#           "sub_type": null,
#           "text": "Cloud Infrastructure",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 5,
#           "meta_info": null,
#           "offset": 110,
#           "score": 0.589793860912323,
#           "sub_type": null,
#           "text": "cloud",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 12,
#           "meta_info": null,
#           "offset": 136,
#           "score": 0.5838329792022705,
#           "sub_type": null,
#           "text": "applications",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 27,
#           "meta_info": null,
#           "offset": 172,
#           "score": 0.6059926152229309,
#           "sub_type": null,
#           "text": "Oracle Cloud Infrastructure",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 3,
#           "meta_info": null,
#           "offset": 205,
#           "score": 0.9935953617095947,
#           "sub_type": null,
#           "text": "AWS",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 5,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 234,
#           "score": 0.9976995587348938,
#           "sub_type": "NUMBER",
#           "text": "First",
#           "type": "QUANTITY"
#         },
#         {
#           "length": 14,
#           "meta_info": null,
#           "offset": 258,
#           "score": 0.9683412313461304,
#           "sub_type": null,
#           "text": "cloud services",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 331,
#           "score": 0.6283573508262634,
#           "sub_type": null,
#           "text": "Oracle",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 6,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 376,
#           "score": 0.9269948601722717,
#           "sub_type": "NUMBER",
#           "text": "Second",
#           "type": "QUANTITY"
#         },
#         {
#           "length": 12,
#           "meta_info": null,
#           "offset": 431,
#           "score": 0.9573898315429688,
#           "sub_type": null,
#           "text": "Oracle Cloud",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 455,
#           "score": 0.8935028314590454,
#           "sub_type": null,
#           "text": "Oracle",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 490,
#           "score": 0.9999524354934692,
#           "sub_type": null,
#           "text": "VMware",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 18,
#           "meta_info": null,
#           "offset": 501,
#           "score": 0.9921504656473795,
#           "sub_type": null,
#           "text": "bare metal servers",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 5,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 526,
#           "score": 0.9976876378059387,
#           "sub_type": "NUMBER",
#           "text": "Third",
#           "type": "QUANTITY"
#         },
#         {
#           "length": 6,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 676,
#           "score": 0.993776261806488,
#           "sub_type": "NUMBER",
#           "text": "Fourth",
#           "type": "QUANTITY"
#         },
#         {
#           "length": 8,
#           "meta_info": null,
#           "offset": 711,
#           "score": 0.9984849691390991,
#           "sub_type": null,
#           "text": "Oracle’s",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 4,
#           "meta_info": null,
#           "offset": 731,
#           "score": 0.9207198619842529,
#           "sub_type": null,
#           "text": "SLAs",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 895,
#           "score": 0.9831865429878235,
#           "sub_type": null,
#           "text": "Oracle",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 20,
#           "meta_info": null,
#           "offset": 902,
#           "score": 0.9501650035381317,
#           "sub_type": null,
#           "text": "Cloud Infrastructure",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 3,
#           "meta_info": null,
#           "offset": 928,
#           "score": 0.8768823146820068,
#           "sub_type": null,
#           "text": "AWS",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 6,
#           "meta_info": null,
#           "offset": 964,
#           "score": 0.7470099925994873,
#           "sub_type": null,
#           "text": "Oracle",
#           "type": "ORGANIZATION"
#         },
#         {
#           "length": 20,
#           "meta_info": null,
#           "offset": 971,
#           "score": 0.6242154240608215,
#           "sub_type": null,
#           "text": "Cloud Infrastructure",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 14,
#           "meta_info": null,
#           "offset": 1001,
#           "score": 0.9327693581581116,
#           "sub_type": null,
#           "text": "cloud platform",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 3,
#           "meta_info": null,
#           "offset": 1021,
#           "score": 0.86944180727005,
#           "sub_type": null,
#           "text": "AWS",
#           "type": "ORGANIZATION"
#         }
#       ],
#       "key": "oci",
#       "language_code": "en"
#     },
#     {
#       "entities": [
#         {
#           "length": 25,
#           "meta_info": null,
#           "offset": 5,
#           "score": 0.9179133375485738,
#           "sub_type": "FACILITY",
#           "text": "restaurant Chinese Garden",
#           "type": "LOCATION"
#         },
#         {
#           "length": 3,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 34,
#           "score": 0.7345984578132629,
#           "sub_type": "NUMBER",
#           "text": "100",
#           "type": "QUANTITY"
#         },
#         {
#           "length": 8,
#           "meta_info": null,
#           "offset": 39,
#           "score": 0.801843523979187,
#           "sub_type": "FACILITY",
#           "text": "Broadway",
#           "type": "LOCATION"
#         },
#         {
#           "length": 6,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 49,
#           "score": 0.9999939203262329,
#           "sub_type": "GPE",
#           "text": "Denver",
#           "type": "LOCATION"
#         },
#         {
#           "length": 4,
#           "meta_info": null,
#           "offset": 83,
#           "score": 0.9926992058753967,
#           "sub_type": null,
#           "text": "meal",
#           "type": "PRODUCT"
#         },
#         {
#           "length": 4,
#           "meta_info": null,
#           "offset": 97,
#           "score": 0.9881677627563477,
#           "sub_type": null,
#           "text": "food",
#           "type": "PRODUCT"
#         }
#       ],
#       "key": "chinese_garden",
#       "language_code": "en"
#     },
#     {
#       "entities": [
#         {
#           "length": 6,
#           "meta_info": {
#             "length": null,
#             "offset": null,
#             "score": null,
#             "sub_type": null,
#             "text": null
#           },
#           "offset": 25,
#           "score": 0.999979555606842,
#           "sub_type": "GPE",
#           "text": "Denver",
#           "type": "LOCATION"
#         },
#         {
#           "length": 9,
#           "meta_info": null,
#           "offset": 44,
#           "score": 0.737904965877533,
#           "sub_type": null,
#           "text": "accidents",
#           "type": "EVENT"
#         },
#         {
#           "length": 15,
#           "meta_info": null,
#           "offset": 82,
#           "score": 0.9760338212904556,
#           "sub_type": null,
#           "text": "help@denver.org",
#           "type": "EMAIL"
#         }
#       ],
#       "key": "Denver",
#       "language_code": "en"
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# ## Text Classification
#
# see: https://docs.oracle.com/en-us/iaas/language/using/text-class.htm

# %%
# Run text classification on text_document
text_classification = lang_client.batch_detect_language_text_classification(
            batch_detect_language_text_classification_details=oci.ai_language.models.BatchDetectLanguageTextClassificationDetails(
                documents=test_docs,compartment_id = compartmentId
            )
        )
print(text_classification.data)
# Out:
# {
#   "documents": [
#     {
#       "key": "oci",
#       "language_code": "en",
#       "text_classification": [
#         {
#           "label": "Computer and Electronics/Enterprise Software",
#           "score": 1.0
#         }
#       ]
#     },
#     {
#       "key": "chinese_garden",
#       "language_code": "en",
#       "text_classification": [
#         {
#           "label": "Food and Grocery/Restaurants",
#           "score": 1.0
#         }
#       ]
#     },
#     {
#       "key": "Denver",
#       "language_code": "en",
#       "text_classification": [
#         {
#           "label": "Autos and Vehicles/Vehicle Parts and Services",
#           "score": 0.151167959
#         }
#       ]
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# # PII Identification
#
# see: https://docs.oracle.com/en-us/iaas/language/using/pii.htm

# %%
piiEntityMasking = oci.ai_language.models.PiiEntityMask(mode="MASK", masking_character="*", leave_characters_unmasked=4,
                                                        is_unmasked_from_end=True)
masking = {"ALL": piiEntityMasking}
pii_identification = lang_client.batch_detect_language_pii_entities(
            batch_detect_language_pii_entities_details=oci.ai_language.models.BatchDetectLanguagePiiEntitiesDetails(
                documents=test_docs,compartment_id = compartmentId,
                masking = masking
            )
        )
print (pii_identification.data)
# Out:
# {
#   "documents": [
#     {
#       "entities": [],
#       "key": "oci",
#       "language_code": "en",
#       "masked_text": "\n    Oracle Cloud Infrastructure is built for enterprises seeking higher performance, lower costs, and easier cloud migration for their applications. \n    Customers choose Oracle Cloud Infrastructure over AWS for several reasons:\n    First, they can consume cloud services in the public cloud or within their  own data center with Oracle Dedicated Region Cloud@Customer. \n    Second, they can migrate and run any workload as is on Oracle Cloud, including Oracle databases and applications, VMware, or bare metal servers. \n    Third, customers can easily implement security controls and automation to prevent misconfiguration errors and implement security best practices. \n    Fourth, they have lower risks with Oracle’s end-to-end SLAs covering performance, availability, and manageability of services. \n    Finally, their workloads achieve better performance at a significantly lower cost with Oracle Cloud Infrastructure than AWS.\n\n    Take a look at what makes Oracle Cloud Infrastructure a better cloud platform than AWS.\"\n"
#     },
#     {
#       "entities": [
#         {
#           "id": "1",
#           "length": 31,
#           "offset": 34,
#           "score": 0.9954520463943481,
#           "text": "100  Broadway, Denver, CO-80503",
#           "type": "ADDRESS"
#         }
#       ],
#       "key": "chinese_garden",
#       "language_code": "en",
#       "masked_text": " The restaurant Chinese Garden on ***************************0503 serves delicious meal, but the food can be expensive."
#     },
#     {
#       "entities": [
#         {
#           "id": "1",
#           "length": 15,
#           "offset": 82,
#           "score": 0.95,
#           "text": "help@denver.org",
#           "type": "EMAIL"
#         }
#       ],
#       "key": "Denver",
#       "language_code": "en",
#       "masked_text": " The wet, slushy rain in Denver can lead to accidents, but if yuo send an emai to ***********.org they will come out and help which is awesome"
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# # Language detection
# https://docs.oracle.com/en-us/iaas/language/using/lang-detect.htm

# %%
# AI Service : Language detection


lang_doc1 = oci.ai_language.models.DominantLanguageDocument(
        key="french",
        text="Et encore une autre langue, es-possible qu'il le comprend ?",
        )

lang_doc2 = oci.ai_language.models.DominantLanguageDocument(
        key="dutch",
        text="Een tekst in mijn moedertaal om het een beetje moeilijker te maken voor de service",
        )
lang_doc3 = oci.ai_language.models.DominantLanguageDocument(
        key="english",
        text="This should be fairly easy to detect, I'll avoid using the name of the actual language in this text",
        )

lang_docs=[lang_doc1, lang_doc2, lang_doc3]

response = lang_client.batch_detect_dominant_language (batch_detect_dominant_language_details=
        oci.ai_language.models.BatchDetectDominantLanguageDetails(documents=lang_docs,compartment_id = compartmentId)
    )

print(response.data)
# Out:
# {
#   "documents": [
#     {
#       "key": "french",
#       "languages": [
#         {
#           "code": "fr",
#           "name": "French",
#           "score": 1.0
#         }
#       ]
#     },
#     {
#       "key": "dutch",
#       "languages": [
#         {
#           "code": "nl",
#           "name": "Dutch",
#           "score": 1.0
#         }
#       ]
#     },
#     {
#       "key": "english",
#       "languages": [
#         {
#           "code": "en",
#           "name": "English",
#           "score": 1.0
#         }
#       ]
#     }
#   ],
#   "errors": []
# }

# %% [markdown]
# # Translation
# https://docs.oracle.com/en-us/iaas/language/using/translate-text.htm

# %%
# Translate a few sentences from English to Dutch.  Feel free to change the text or the languages


key1 = "doc1"
key2 = "doc2"
text1 = "The Indy Autonomous Challenge is the worlds first head-to-head, high speed autonomous race taking place at the Indianapolis Motor Speedway"
text2 = "OCI will be the cloud engine for the artificial intelligence models that drive the MIT Driverless cars."
target_language = "nl" #TODO specify the target language

doc1 = oci.ai_language.models.TextDocument(key=key1, text=text1, language_code="en")
doc2 = oci.ai_language.models.TextDocument(key=key2, text=text2, language_code="en")
documents = [doc1, doc2]


batch_language_translation_details = oci.ai_language.models.BatchLanguageTranslationDetails(
    documents=documents, 
    compartment_id=compartmentId, 
    target_language_code=target_language)
output = lang_client.batch_language_translation (batch_language_translation_details)
print(output.data)
# Out:
# {
#   "documents": [
#     {
#       "key": "doc1",
#       "source_language_code": "en",
#       "target_language_code": "nl",
#       "translated_text": "De Indy Autonomous Challenge is 's werelds eerste head-to-head, high speed autonome race die plaatsvindt op de Indianapolis Motor Speedway"
#     },
#     {
#       "key": "doc2",
#       "source_language_code": "en",
#       "target_language_code": "nl",
#       "translated_text": "OCI wordt de cloud-engine voor de kunstmatige-intelligentiemodellen die de MIT Driverless-auto's besturen."
#     }
#   ],
#   "errors": []
# }
