# %% [markdown]
# ## Document Understanding
# documentation:  https://docs.oracle.com/en-us/iaas/Content/document-understanding/using/home.htm
#
# slack: #oci_ai_document_service_users or #igiu-innovation-lab if you have quesytion on service
#
# issues with code: #igiu-ai-learning

# %% [markdown]
# ## Import Libraries

# %%
import oci
import io
from oci.object_storage import ObjectStorageClient
import json,os,io
from dotenv import load_dotenv
from envyaml import EnvYAML

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Set input variables

# %%
#####
#make sure your sandbox.yaml file is setup for your environment. You might have to specify the full path depending on  your `cwd` 
# you can also try making your cwd ofr jupyter match your workspace python code: 
# vscopde menu -> Settings > Extensions > Jupyter > Notebook File Root
# change from ${fileDirname} to ${workspaceFolder}
#####


SANDBOX_CONFIG_FILE = "sandbox.yaml"

FILE_TO_ANALYZE = "./vision/dussera-b.jpg"

# %% [markdown]
# # Read the config file

# %%
def load_config(config_path):
    try:
        return EnvYAML(config_path)
    except FileNotFoundError:
        print(f"Error: Configuration file '{config_path}' not found.")
        return None

scfg = load_config(SANDBOX_CONFIG_FILE)

oci_cfg = oci.config.from_file(os.path.expanduser(scfg["oci"]["configFile"]),scfg["oci"]["profile"])
bucket_cfg = scfg["bucket"]
namespace = bucket_cfg["namespace"]
bucketName =  bucket_cfg["bucketName"]
filename = os.path.basename(FILE_TO_ANALYZE)
prefix = bucket_cfg['prefix']
compartmentId =scfg["oci"]["compartment"]

# %% [markdown]
# ## Upload file
#
# This is an optional step. If the file is already uploaded, no need to upload it again.

# %%
object_storage_client = ObjectStorageClient(oci_cfg)
print(f"Uploading file {FILE_TO_ANALYZE} ...")
object_storage_client.put_object(bucket_cfg["namespace"], 
                                bucket_cfg["bucketName"], 
                                f"{bucket_cfg['prefix']}/{os.path.basename(FILE_TO_ANALYZE)}", 
                                io.open(FILE_TO_ANALYZE,'rb'))
print("Upload completed !")
# Out:
# Uploading file ./vision/dussera-b.jpg ...
# Upload completed !

# %% [markdown]
# ## Create a callback function to print the status

# %%
def create_processor_job_callback(times_called, response):
    print("Waiting for processor lifecycle state to go into succeeded state:", response.data)

# %% [markdown]
# ## Create AI service vision client

# %%
dus_client = oci.ai_document.AIServiceDocumentClientCompositeOperations(oci.ai_document.AIServiceDocumentClient(config=oci_cfg))

# %% [markdown]
# ## Setup  features to be analyzed
# You can specify the features you want to call. In the below code we are calling all the features

# %%
features = [ oci.ai_document.models.DocumentClassificationFeature(),
            oci.ai_document.models.DocumentLanguageClassificationFeature(), 
            oci.ai_document.models.DocumentKeyValueExtractionFeature(),
            oci.ai_document.models.DocumentTableExtractionFeature(),
            oci.ai_document.models.DocumentTextExtractionFeature()
            ]

# %% [markdown]
# ## Setup input location

# %%
input_location = oci.ai_document.models.ObjectLocation()
input_location.namespace_name = namespace
input_location.bucket_name =   bucketName
input_location.object_name = f"{prefix}/{filename}"

# %% [markdown]
# ## Setup output location

# %%
output_location = oci.ai_document.models.OutputLocation()
output_location.namespace_name =  namespace
output_location.bucket_name =  bucketName
output_location.prefix = prefix

# %% [markdown]
# ## Create image job

# %%
display_name = f"{prefix}-test"
job_details = oci.ai_document.models.CreateProcessorJobDetails(
                                    display_name=display_name,
                                    compartment_id=compartmentId,
                                    input_location=oci.ai_document.models.ObjectStorageLocations(object_locations=[input_location]),
                                    output_location= output_location,
                                    processor_config=oci.ai_document.models.GeneralProcessorConfig(features=features)
                                    )

# %% [markdown]
# ## Job in progress
# The job progress is tracked till completion with an interval of 5 seconds.

# %%
processor= dus_client.create_processor_job_and_wait_for_state(
    create_processor_job_details=job_details,
    wait_for_states=[oci.ai_document.models.ProcessorJob.LIFECYCLE_STATE_SUCCEEDED],
    waiter_kwargs={"wait_callback": create_processor_job_callback})
# Out:
# ---------------------------------------------------------------------------
# TransientServiceError                     Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 processor= dus_client.create_processor_job_and_wait_for_state(
#       2     create_processor_job_details=job_details,
#       3     wait_for_states=[oci.ai_document.models.ProcessorJob.LIFECYCLE_STATE_SUCCEEDED],
#       4     waiter_kwargs={"wait_callback": create_processor_job_callback})
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/ai_document/ai_service_document_client_composite_operations.py:175, in AIServiceDocumentClientCompositeOperations.create_processor_job_and_wait_for_state(self, create_processor_job_details, wait_for_states, operation_kwargs, waiter_kwargs)
#     157 def create_processor_job_and_wait_for_state(self, create_processor_job_details, wait_for_states=[], operation_kwargs={}, waiter_kwargs={}):
#     158     """
#     159     Calls :py:func:`~oci.ai_document.AIServiceDocumentClient.create_processor_job` and waits for the :py:class:`~oci.ai_document.models.ProcessorJob` acted upon
#     160     to enter the given state(s).
#    (...)    173         as dictionary keys to modify how long the waiter function will wait between retries and the maximum amount of time it will wait
#     174     """
# --> 175     operation_result = self.client.create_processor_job(create_processor_job_details, **operation_kwargs)
#     176     if not wait_for_states:
#     177         return operation_result
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/ai_document/ai_service_document_client.py:1099, in AIServiceDocumentClient.create_processor_job(self, create_processor_job_details, **kwargs)
#    1097         self.base_client.add_opc_client_retries_header(header_params)
#    1098         retry_strategy.add_circuit_breaker_callback(self.circuit_breaker_callback)
# -> 1099     return retry_strategy.make_retrying_call(
#    1100         self.base_client.call_api,
#    1101         resource_path=resource_path,
#    1102         method=method,
#    1103         header_params=header_params,
#    1104         body=create_processor_job_details,
#    1105         response_type="ProcessorJob",
#    1106         allow_control_chars=kwargs.get('allow_control_chars'),
#    1107         operation_name=operation_name,
#    1108         api_reference_link=api_reference_link,
#    1109         required_arguments=required_arguments)
#    1110 else:
#    1111     return self.base_client.call_api(
#    1112         resource_path=resource_path,
#    1113         method=method,
#    (...)   1119         api_reference_link=api_reference_link,
#    1120         required_arguments=required_arguments)
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/retry/retry.py:308, in ExponentialBackoffRetryStrategyBase.make_retrying_call(self, func_ref, *func_args, **func_kwargs)
#     305 if _should_record_body_position_for_retry:
#     306     # Attempt to save current position for file-like body
#     307     _is_body_retryable, body_position = record_body_position_for_rewind(func_kwargs.get('body'))
# --> 308 response = func_ref(*func_args, **func_kwargs)
#     309 time_elapsed = time.time() - start_time
#     311 if log_info["logger"] and log_info["debug"]:
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/base_client.py:548, in BaseClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, response_type, enforce_content_headers, allow_control_chars, enable_strict_url_encoding, operation_name, api_reference_link, required_arguments)
#     546 else:
#     547     start = timer()
# --> 548     response = self.request(request, allow_control_chars, operation_name, api_reference_link)
#     549     end = timer()
#     550     self.logger.debug('time elapsed for request: {}'.format(str(end - start)))
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/circuitbreaker.py:146, in CircuitBreaker._decorate_sync.<locals>.wrapper(*args, **kwargs)
#     144         return self.fallback_function(*args, **kwargs)
#     145     raise CircuitBreakerError(self)
# --> 146 return self.call(function, *args, **kwargs)
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/circuitbreaker.py:188, in CircuitBreaker.call(self, func, *args, **kwargs)
#     182 """
#     183 Calls the decorated function and applies the circuit breaker
#     184 rules on success or failure
#     185 :param func: Decorated function
#     186 """
#     187 with self:
# --> 188     return func(*args, **kwargs)
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/base_client.py:738, in BaseClient.request(self, request, allow_control_chars, operation_name, api_reference_link)
#     736     if initial_circuit_breaker_state != new_circuit_breaker_state:
#     737         self.logger.warning("Circuit Breaker state changed from {} to {}".format(initial_circuit_breaker_state, new_circuit_breaker_state))
# --> 738     self.raise_transient_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     739 else:
#     740     self.raise_service_error(request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#
# File ~/work/code/python/workshop/.venv/lib/python3.13/site-packages/oci/base_client.py:920, in BaseClient.raise_transient_service_error(self, request, response, service_code, message, operation_name, api_reference_link, target_service, request_endpoint, client_version, timestamp, deserialized_data)
#     919 def raise_transient_service_error(self, request, response, service_code, message, operation_name=None, api_reference_link=None, target_service=None, request_endpoint=None, client_version=None, timestamp=None, deserialized_data=None):
# --> 920     raise exceptions.TransientServiceError(
#     921         response.status_code,
#     922         service_code,
#     923         response.headers,
#     924         message,
#     925         original_request=request,
#     926         operation_name=operation_name,
#     927         api_reference_link=api_reference_link,
#     928         target_service=target_service,
#     929         request_endpoint=request_endpoint,
#     930         client_version=client_version,
#     931         timestamp=timestamp,
#     932         deserialized_data=deserialized_data)
#
# TransientServiceError: {'target_service': 'ai_service_document', 'status': 500, 'code': 500, 'opc-request-id': '7A68EA795A2942F6BF17334A5BF125A5/4910FDF9EE20888ACFC40C69504858CB/4FC3470B2CD22E5888C2D989BF4F1814', 'message': 'There was an error processing your request. It has been logged (ID 6876bed604b930b8).', 'operation_name': 'create_processor_job', 'timestamp': '2025-11-06T15:54:56.856474+00:00', 'client_version': 'Oracle-PythonSDK/2.161.1', 'request_endpoint': 'POST https://document.aiservice.us-phoenix-1.oci.oraclecloud.com/20221109/processorJobs', 'logging_tips': 'To get more info on the failing request, refer to https://docs.oracle.com/en-us/iaas/tools/python/latest/logging.html for ways to log the request/response details.', 'troubleshooting_tips': "See https://docs.oracle.com/iaas/Content/API/References/apierrors.htm#apierrors_500__500_500 for more information about resolving this error. Also see https://docs.oracle.com/iaas/api/#/en/document-understanding/20221109/ProcessorJob/CreateProcessorJob for details on this operation's requirements. If you are unable to resolve this ai_service_document issue, please contact Oracle support and provide them this full error message."}

# %% [markdown]
# ## Get response json from object storage
# The output can be found in the output location specified or it can be saved in ```output.json``` file by running the below cell

# %%
print(f"processor call succeeded with status: {[processor.status]} and request_id: {processor.request_id}.")
processor_job: oci.ai_document.models.ProcessorJob = processor.data

print(f"Getting result json from the output_location {processor_job.id}")

object_storage_client = oci.object_storage.ObjectStorageClient(config=oci_cfg)
get_object_response = object_storage_client.get_object(namespace_name=namespace,
                                                       bucket_name=bucketName,
                                                       object_name=f"{prefix}/{processor_job.id}/{namespace}_{bucketName}/results/{prefix}/{filename}.json")

print(str(get_object_response.data.content.decode()))

# %% [markdown]
# ## Exercise 1 : Dcument Validator
#
# 1. Create a document in PowerPoint with
#     * Name
#     * Address
#     * Dates
#     * Create date
#     * Expiry date
#     * Signature
#
# 1. Save it as an image
#
# 1. Use Document Understanding & LLM service to validate
#     *  is on correct name
#     *  is on correct address
#     *  is not expired
#     *  has a signature

# %% [markdown]
# ## Exercise 2 : Form Filler
#
# 1. Upload a receipt
# 1. Fill out a expense report based on the receipt
#     *  Image an expense resporr as an multi line f string for simplicity
